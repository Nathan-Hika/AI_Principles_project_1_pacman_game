# %% [markdown]
# <a href="https://colab.research.google.com/github/Nathan-Hika/AI_Principles_project_1_pacman_game/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    'A/C Model': ['B767-300BDSF','B767-300BDSF','B767-300F','B767-300F','B767-300ER'],
    'Registration': ['ET-ALO', 'ET-ALP', 'ET-BBE', 'ET-BBF', '3C-MAG'],
    'Variable': ['VS882', 'VS883', 'VT731', 'VT732', 'VS137'],
    'Effectivity': ['302', '303', '662', '663', 'ILF012'],
    'Serial': ['33768', '33769', '67023', '67024', '30393'],
    'Line': ['922', '933', '1258', '1263', '781'],
    'Engine type': ['PW4062-3', 'PW4062-3', 'CF6-80C2B6F', 'CF6-80C2B6F', 'CF6-80C2B6F'],
    'APU': ['GTCP-331', 'GTCP-331', 'GTCP-331', 'GTCP-331', 'GTCP-331']
}

df = pd.DataFrame(data)
display(df)
# Out:
#       A/C Model Registration Variable Effectivity Serial  Line  Engine type  \
# 0  B767-300BDSF       ET-ALO    VS882         302  33768   922     PW4062-3
# 1  B767-300BDSF       ET-ALP    VS883         303  33769   933     PW4062-3
# 2     B767-300F       ET-BBE    VT731         662  67023  1258  CF6-80C2B6F
# 3     B767-300F       ET-BBF    VT732         663  67024  1263  CF6-80C2B6F
# 4    B767-300ER       3C-MAG    VS137      ILF012  30393   781  CF6-80C2B6F
#
#         APU
# 0  GTCP-331
# 1  GTCP-331
# 2  GTCP-331
# 3  GTCP-331
# 4  GTCP-331
